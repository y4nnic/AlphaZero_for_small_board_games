# %% [markdown]
# # Experiment - Optimized Connect4

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from pipeline import Pipeline

# %% [markdown]
# ## Run

# %%
test_pipeline = Pipeline("test_cf_opt", "Connect4")

# %%
wins, draws = test_pipeline.run(10)
# Out:
# iteration 0 | self-play
# game 0
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 1
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 2
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 3
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 4
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 5
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 6
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 7
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 8
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 9
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 10
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 11
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 12
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 13
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 14
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 15
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 16
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 17
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 18
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 19
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 20
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 21
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 22
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 23
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 24
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 25
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 26
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 27
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 28
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 29
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 30
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 31
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 32
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 33
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 34
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 35
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 36
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 37
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 38
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 39
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 40
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 41
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 42
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 43
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 44
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 45
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 46
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 47
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 48
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 49
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 50
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 51
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 52
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 53
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 54
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 55
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 56
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 57
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 58
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 59
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 60
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 61
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 62
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 63
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 64
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 65
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 66
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 67
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 68
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 69
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 70
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 71
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 72
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 73
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 74
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 75
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 76
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 77
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 78
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 79
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 80
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 81
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 82
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 83
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 84
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 85
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 86
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 87
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 88
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 89
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 90
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 91
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 92
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 93
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 94
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 95
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 96
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 97
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 98
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# game 99
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# turn
# saving memory position_memory_test_cf_opt_ep_0
# iteration 0 | optimization
# num_positions: 5120
# model_X shape: (1321, 6, 7, 3)
# model_y_outcomes: (1321,)
# model_y_probabilities: (1321, 7)
# Train on 1056 samples, validate on 265 samples
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fe1c61b80d38> in <module>()
# ----> 1 test_pipeline.run(10)
#
# ~/Documents/Informatik/BA/AlphaZero_for_small_board_games/pipeline.py in run(self, num_iterations)
#      70             #self.logger.info("Pipeline: ######## Iteration {} | Optimization ########".format(iteration))
#      71             print("iteration {} | optimization".format(iteration))
# ---> 72             self.optimization(iteration)
#      73
#      74             #self.logger.info("Pipeline: ######## Iteration {} | Evaluation ########".format(iteration))
#
# ~/Documents/Informatik/BA/AlphaZero_for_small_board_games/pipeline.py in optimization(self, iteration)
#     103             )
#     104         self.model.train()
# --> 105
#     106     def evaluation(self):
#     107         """ TODO docstring evaluation """
#
# ~/Documents/Informatik/BA/AlphaZero_for_small_board_games/model.py in train(self)
#      86             batch_size=batch_size,
#      87             epochs=num_epochs,
# ---> 88             verbose=1
#      89         )
#      90
#
# ~/Documents/Informatik/BA/AlphaZero_for_small_board_games/neural_networks.py in fit(self, X, y, batch_size, epochs, verbose)
#      65             verbose=verbose,
#      66             validation_split=0.2,
# ---> 67             callbacks=[self.tensorboard]
#      68         )
#      69
#
# /Applications/anaconda3/envs/AZ_for_small_board_games/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# /Applications/anaconda3/envs/AZ_for_small_board_games/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /Applications/anaconda3/envs/AZ_for_small_board_games/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# /Applications/anaconda3/envs/AZ_for_small_board_games/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# /Applications/anaconda3/envs/AZ_for_small_board_games/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ## evluation

# %%
fig = plt.figure()

plt.title("Evaluation")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(10)
losses = np.ones(20) - wins - draws
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins, label="win ratio")
plt.plot(x, draws, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
import numpy as np
import copy
import memory

class Connect4Optimized():
    
    def __init__(self):
        self.player_1 = 0
        self.player_2 = 1

        self.board_height = 6
        self.board_width = 7
        self.board_size = self.board_height * self.board_width

        board_p1 = 0b000000000000000000000000000000000000000000
        board_p2 = 0b000000000000000000000000000000000000000000

        self.boards = [board_p2, board_p2]
        self.legal_moves = np.ones(self.board_width, dtype=np.uint8)
        self.current_player = self.player_1
        self.column_counts = np.zeros(self.board_width, dtype=np.uint8)
        self.turn = 0

        self.boards_simulation = [board_p1, board_p2]
        self.legal_moves_simulation = np.ones(self.board_size, dtype=np.uint8)
        self.current_player_simulation = self.current_player
        self.column_counts_simulation = np.zeros(self.board_width, dtype=np.uint8)
        self.turn_simulation = self.turn
    
    def get_len_action_space(self):
        return self.board_width

    def reset_simulation(self):
        self.boards_simulation = copy.deepcopy(self.boards)
        self.legal_moves_simulation = copy.deepcopy(self.legal_moves)
        self.current_player_simulation = self.current_player
        self.column_counts_simulation = copy.deepcopy(self.column_counts)
        self.turn_simulations = self.turn
        
    def reset_game(self):
        board_p1 = 0b000000000000000000000000000000000000000000
        board_p2 = 0b000000000000000000000000000000000000000000

        self.boards = [board_p2, board_p2]
        self.legal_moves = np.ones(self.board_size, dtype=np.uint8)
        self.current_player = self.player_1
        self.column_counts = np.zeros(self.board_width, dtype=np.uint8)
        self.turn = 0

    def execute_move(self, action):
        if self.legal_moves[action] == 1:
            move = 1 << (6 - action + 7*self.column_counts[action])
            self.boards[self.current_player] |= move
            
            self.column_counts[action] +=1
            
            if self.column_counts[action] == 6:
                self.legal_moves[action] = 0
        else:
            print("Illegal Move!")
            
        winning = self.is_winning()
        self.current_player = 1 - self.current_player
        self.turn += 1
        return winning

    def is_winning(self):
        # vertical check
        board = self.boards[self.current_player]
        board = board & (board >> 7)
        if board & (board >> 14):
            return 1
        
        # horizontal check
        board = self.boards[self.current_player]
        board = board & (board >> 1)
        if board & (board >> 2):
            return 1
        
        # diagonal \
        board = self.boards[self.current_player]
        board = board & (board >> 8)
        if board & (board >> 16):
            return 1
        
        # diagonal /
        board = self.boards[self.current_player]
        board = board & (board >> 6)
        if board & (board >> 12):
            return 1
        return 0
        
    def get_current_position(self):
        pieces_p1 = self.board_to_array(self.boards[self.player_1])
        pieces_p2 = self.board_to_array(self.boards[self.player_2])

        if self.current_player == self.player_1:
            colour = np.ones((self.board_height, self.board_width, 1), dtype=np.uint8)
            state = np.concatenate((pieces_p1, pieces_p2, colour), axis=2)

        if self.current_player == self.player_2:
            colour = np.zeros((self.board_height, self.board_width, 1), dtype=np.uint8)
            state = np.concatenate((pieces_p2, pieces_p1, colour), axis=2)

        return memory.Position(state, self.legal_moves)

    def simulate_move(self, action):
        if self.legal_moves_simulation[action] == 1:
            move = 1 << (6 - action + 7*self.column_counts_simulation[action])
            self.boards_simulation[self.current_player_simulation] |= move
            
            self.column_counts_simulation[action] += 1
            
            if self.column_counts_simulation[action] == 6:
                self.legal_moves_simulation[action] = 0
        else:
            print("Illegal Move (Simulation)!")
        
        winning = self.is_winning_simulation()
        self.turn_simulation += 1
        return winning
    
    def is_winning_simulation(self):
        # vertical check
        board = self.boards_simulation[self.current_player_simulation]
        board = board & (board >> 7)
        if board & (board >> 14):
            return 1
        
        # horizontal check
        board = self.boards_simulation[self.current_player_simulation]
        board = board & (board >> 1)
        if board & (board >> 2):
            return 1
        
        # diagonal \
        board = self.boards_simulation[self.current_player_simulation]
        board = board & (board >> 8)
        if board & (board >> 16):
            return 1
        
        # diagonal /
        board = self.boards_simulation[self.current_player_simulation]
        board = board & (board >> 6)
        if board & (board >> 12):
            return 1
        return 0

    def get_current_position_simulation(self):
        pieces_p1 = self.board_to_array(self.boards_simulation[self.player_1])
        pieces_p2 = self.board_to_array(self.boards_simulation[self.player_2])

        if self.current_player_simulation == self.player_1:
            colour = np.ones((self.board_height, self.board_width, 1), dtype=np.uint8)
            state = np.concatenate((pieces_p1, pieces_p2, colour), axis=2)

        if self.current_player_simulation == self.player_2:
            colour = np.zeros((self.board_height, self.board_width, 1), dtype=np.uint8)
            state = np.concatenate((pieces_p2, pieces_p1, colour), axis=2)

        return memory.Position(state, self.legal_moves_simulation)
    
    def board_to_array(self,board_bin):  
        board = np.zeros((6,7,1), dtype=np.uint8)
        print("board_bin {}" .format(bin(board_bin)))
        board[0,0] = board_bin >> 41
        board[0,1] = (board_bin & 0b10000000000000000000000000000000000000000) >> 40 
        board[0,2] = (board_bin & 0b1000000000000000000000000000000000000000) >> 39
        board[0,3] = (board_bin & 0b100000000000000000000000000000000000000) >> 38
        board[0,4] = (board_bin & 0b10000000000000000000000000000000000000) >> 37
        board[0,5] = (board_bin & 0b1000000000000000000000000000000000000) >> 36
        board[0,6] = (board_bin & 0b100000000000000000000000000000000000) >> 35
        board[1,0] = (board_bin & 0b10000000000000000000000000000000000) >> 34
        board[1,1] = (board_bin & 0b1000000000000000000000000000000000) >> 33
        board[1,2] = (board_bin & 0b100000000000000000000000000000000) >> 32
        board[1,3] = (board_bin & 0b10000000000000000000000000000000) >> 31
        board[1,4] = (board_bin & 0b1000000000000000000000000000000) >> 30
        board[1,5] = (board_bin & 0b100000000000000000000000000000) >> 29
        board[1,6] = (board_bin & 0b10000000000000000000000000000) >> 28
        board[2,0] = (board_bin & 0b1000000000000000000000000000) >> 27
        board[2,1] = (board_bin & 0b100000000000000000000000000) >> 26
        board[2,2] = (board_bin & 0b10000000000000000000000000) >> 25
        board[2,3] = (board_bin & 0b1000000000000000000000000) >> 24
        board[2,4] = (board_bin & 0b100000000000000000000000) >> 23
        board[2,5] = (board_bin & 0b10000000000000000000000) >> 22
        board[2,6] = (board_bin & 0b1000000000000000000000) >> 21
        board[3,0] = (board_bin & 0b100000000000000000000) >> 20
        board[3,1] = (board_bin & 0b10000000000000000000) >> 19
        board[3,2] = (board_bin & 0b1000000000000000000) >> 18
        board[3,3] = (board_bin & 0b100000000000000000) >> 17
        board[3,4] = (board_bin & 0b10000000000000000) >> 16
        board[3,5] = (board_bin & 0b1000000000000000) >> 15
        board[3,6] = (board_bin & 0b100000000000000) >> 14
        board[4,0] = (board_bin & 0b10000000000000) >> 13
        board[4,1] = (board_bin & 0b1000000000000) >> 12
        board[4,2] = (board_bin & 0b100000000000) >> 11
        board[4,3] = (board_bin & 0b10000000000) >> 10
        board[4,4] = (board_bin & 0b1000000000) >> 9
        board[4,5] = (board_bin & 0b100000000) >> 8
        board[4,6] = (board_bin & 0b10000000) >> 7
        board[5,0] = (board_bin & 0b1000000) >> 6
        board[5,1] = (board_bin & 0b100000) >> 5
        board[5,2] = (board_bin & 0b10000) >> 4
        board[5,3] = (board_bin & 0b1000) >> 3
        board[5,4] = (board_bin & 0b100) >> 2
        board[5,5] = (board_bin & 0b10) >> 1
        board[5,6] = board_bin & 0b1
        print("board {}" .format(board))
        return board

# %%
test_game = Connect4Optimized()

# %%
test_game.reset_game()
test_game.execute_move(0)
test_game.execute_move(1)

test_game.execute_move(1)
test_game.execute_move(2)

position = test_game.get_current_position()
board = position.state[:,:,0] + position.state[:,:,1]
print("board")
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[0,0],
    board[0,1],
    board[0,2],
    board[0,3],
    board[0,4],
    board[0,5],
    board[0,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[1,0],
    board[1,1],
    board[1,2],
    board[1,3],
    board[1,4],
    board[1,5],
    board[1,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[2,0],
    board[2,1],
    board[2,2],
    board[2,3],
    board[2,4],
    board[2,5],
    board[2,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[3,0],
    board[3,1],
    board[3,2],
    board[3,3],
    board[3,4],
    board[3,5],
    board[3,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[4,0],
    board[4,1],
    board[4,2],
    board[4,3],
    board[4,4],
    board[4,5],
    board[4,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[5,0],
    board[5,1],
    board[5,2],
    board[5,3],
    board[5,4],
    board[5,5],
    board[5,6]
))
test_game.execute_move(3)
test_game.execute_move(2)

test_game.execute_move(2)
test_game.execute_move(3)

test_game.execute_move(4)
test_game.execute_move(3)

winning = test_game.execute_move(3)

position = test_game.get_current_position()
board = position.state[:,:,1] + 2*position.state[:,:,0]
print("board")
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[0,0],
    board[0,1],
    board[0,2],
    board[0,3],
    board[0,4],
    board[0,5],
    board[0,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[1,0],
    board[1,1],
    board[1,2],
    board[1,3],
    board[1,4],
    board[1,5],
    board[1,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[2,0],
    board[2,1],
    board[2,2],
    board[2,3],
    board[2,4],
    board[2,5],
    board[2,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[3,0],
    board[3,1],
    board[3,2],
    board[3,3],
    board[3,4],
    board[3,5],
    board[3,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[4,0],
    board[4,1],
    board[4,2],
    board[4,3],
    board[4,4],
    board[4,5],
    board[4,6]
))
print("{}|{}|{}|{}|{}|{}|{}" .format(
    board[5,0],
    board[5,1],
    board[5,2],
    board[5,3],
    board[5,4],
    board[5,5],
    board[5,6]
))



print("winning: {}" .format(winning))

# %%
boards = test_game.get_current_position()
print(bin(boards[0]))
print(bin(boards[1]))

# %%
test_game.execute_move(6)

# %%
boards = test_game.get_current_position()
print(bin(boards[0]))
print(bin(boards[1]))

# %%
test_game.execute_move(6)
boards = test_game.get_current_position()
print(bin(boards[0]))
print(bin(boards[1]))

test_game.execute_move(6)
boards = test_game.get_current_position()
print(bin(boards[0]))
print(bin(boards[1]))

test_game.execute_move(6)
boards = test_game.get_current_position()
print(bin(boards[0]))
print(bin(boards[1]))

# %%
test_game.execute_move(6)
boards = test_game.get_current_position()
print(bin(boards[0]))
print(bin(boards[1]))

# %%
test_game.execute_move(6)

# %%
test = 0b100000000000000000000000000000000000000000

# %%
bin(test >> 41)
