# %% [markdown]
# # Experiment: TicTacToe - Number of Batches

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

from pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1 batch

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 1,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.02, 
    'regularization_strength': 0.001,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_1_batch", "TicTacToe")

# %%
wins_1, draws_1 = test_pipeline.run(50)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_1_batch_ep_0
# iteration 0 | optimization
# num_positions: 512
# model_X shape: (512, 3, 3, 3)
# model_y_outcomes: (512,)
# model_y_probabilities: (512, 9)
# Train on 409 samples, validate on 103 samples
# Epoch 1/10
# 409/409 [==============================] - 3s 7ms/step - loss: 5.5065 - value_loss: 1.3227 - policy_loss: 2.5752 - val_loss: 8753296.0000 - val_value_loss: 1.9417 - val_policy_loss: 17506588.0000
# Epoch 2/10
# 409/409 [==============================] - 0s 149us/step - loss: 13.6303 - value_loss: 1.8680 - policy_loss: 15.4951 - val_loss: 177887.7969 - val_value_loss: 1.9417 - val_policy_loss: 355758.2500
# Epoch 3/10
# 409/409 [==============================] - 0s 152us/step - loss: 15.8913 - value_loss: 1.8680 - policy_loss: 14.5652 - val_loss: 21232.5508 - val_value_loss: 1.9417 - val_policy_loss: 42441.1602
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - 1 batch")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(50)
losses_1 = np.ones(50) - wins_1 - draws_1
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_1, label="win ratio")
plt.plot(x, draws_1, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_1, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
print(wins_1)
print(draws_1)
print(losses_1)
# Out:
# [0.5, 0.44, 0.6, 0.82, 0.9, 0.88, 0.84, 0.86, 0.74, 0.88, 0.86, 0.84, 0.74, 0.78, 0.8, 0.92, 0.82, 0.76, 0.86, 0.88, 0.86, 0.62, 0.88, 0.76, 0.72, 0.76, 0.76, 0.88, 0.86, 0.9, 0.76, 0.8, 0.8, 0.8, 0.74, 0.76, 0.86, 0.86, 0.8, 0.86, 0.76, 0.72, 0.9, 0.72, 0.84, 0.84, 0.84, 0.7, 0.76, 0.86]
# [0.04, 0.04, 0.08, 0.0, 0.0, 0.0, 0.02, 0.04, 0.04, 0.02, 0.04, 0.02, 0.06, 0.08, 0.04, 0.0, 0.04, 0.0, 0.0, 0.02, 0.0, 0.12, 0.02, 0.02, 0.0, 0.04, 0.08, 0.0, 0.02, 0.0, 0.04, 0.04, 0.0, 0.02, 0.04, 0.0, 0.04, 0.04, 0.0, 0.0, 0.08, 0.04, 0.0, 0.02, 0.04, 0.0, 0.02, 0.04, 0.02, 0.04]
# [0.46 0.52 0.32 0.18 0.1  0.12 0.14 0.1  0.22 0.1  0.1  0.14 0.2  0.14
#  0.16 0.08 0.14 0.24 0.14 0.1  0.14 0.26 0.1  0.22 0.28 0.2  0.16 0.12
#  0.12 0.1  0.2  0.16 0.2  0.18 0.22 0.24 0.1  0.1  0.2  0.14 0.16 0.24
#  0.1  0.26 0.12 0.16 0.14 0.26 0.22 0.1 ]

# %% [markdown]
# ## 2 batches

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 2,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.02, 
    'regularization_strength': 0.001,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_2_batches", "TicTacToe")

# %%
wins_2, draws_2 = test_pipeline.run(50)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_2_batches_ep_0
# iteration 0 | optimization
# num_positions: 1024
# model_X shape: (1024, 3, 3, 3)
# model_y_outcomes: (1024,)
# model_y_probabilities: (1024, 9)
# Train on 819 samples, validate on 205 samples
# Epoch 1/10
# 819/819 [==============================] - 3s 4ms/step - loss: 8.4846 - value_loss: 1.7044 - policy_loss: 7.1454 - val_loss: 126959.0859 - val_value_loss: 2.3805 - val_policy_loss: 253900.9219
# Epoch 2/10
# 819/819 [==============================] - 0s 132us/step - loss: 16.9135 - value_loss: 2.2955 - policy_loss: 14.3558 - val_loss: 18085.6055 - val_value_loss: 2.3805 - val_policy_loss: 36141.4844
# Epoch 3/10
# 819/819 [==============================] - 0s 127us/step - loss: 20.8806 - value_loss: 2.2955 - policy_loss: 9.8967 - val_loss: 3767.9399 - val_value_loss: 2.3805 - val_policy_loss: 7495.0366
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - 2 batches")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(50)
losses_2 = np.ones(50) - wins_2 - draws_2
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_2, label="win ratio")
plt.plot(x, draws_2, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_2, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
print(wins_2)
print(draws_2)
print(losses_2)
# Out:
# [0.42, 0.64, 0.76, 0.7, 0.78, 0.8, 0.76, 0.76, 0.72, 0.76, 0.78, 0.76, 0.9, 0.84, 0.82, 0.76, 0.8, 0.82, 0.9, 0.66, 0.82, 0.74, 0.82, 0.9, 0.8, 0.72, 0.76, 0.62, 0.86, 0.76, 0.72, 0.74, 0.74, 0.82, 0.72, 0.6, 0.9, 0.86, 0.64, 0.78, 0.72, 0.82, 0.78, 0.8, 0.76, 0.86, 0.88, 0.6, 0.76, 0.8]
# [0.16, 0.08, 0.04, 0.06, 0.02, 0.04, 0.04, 0.04, 0.04, 0.0, 0.06, 0.06, 0.0, 0.04, 0.04, 0.12, 0.06, 0.06, 0.0, 0.12, 0.06, 0.06, 0.0, 0.04, 0.04, 0.04, 0.04, 0.08, 0.02, 0.04, 0.06, 0.14, 0.06, 0.08, 0.02, 0.08, 0.04, 0.04, 0.1, 0.02, 0.1, 0.02, 0.02, 0.06, 0.04, 0.04, 0.02, 0.1, 0.02, 0.02]
# [0.42 0.28 0.2  0.24 0.2  0.16 0.2  0.2  0.24 0.24 0.16 0.18 0.1  0.12
#  0.14 0.12 0.14 0.12 0.1  0.22 0.12 0.2  0.18 0.06 0.16 0.24 0.2  0.3
#  0.12 0.2  0.22 0.12 0.2  0.1  0.26 0.32 0.06 0.1  0.26 0.2  0.18 0.16
#  0.2  0.14 0.2  0.1  0.1  0.3  0.22 0.18]

# %% [markdown]
# ## 4 batches

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 4,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.02, 
    'regularization_strength': 0.001,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_4_batches", "TicTacToe")

# %%
wins_3, draws_3 = test_pipeline.run(50)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_4_batches_ep_0
# iteration 0 | optimization
# num_positions: 2048
# model_X shape: (2048, 3, 3, 3)
# model_y_outcomes: (2048,)
# model_y_probabilities: (2048, 9)
# Train on 1638 samples, validate on 410 samples
# Epoch 1/10
# 1638/1638 [==============================] - 3s 2ms/step - loss: 12.2408 - value_loss: 1.8058 - policy_loss: 11.3571 - val_loss: 8871.4844 - val_value_loss: 2.2439 - val_policy_loss: 17712.8887
# Epoch 2/10
# 1638/1638 [==============================] - 0s 120us/step - loss: 23.0206 - value_loss: 2.0879 - policy_loss: 9.5535 - val_loss: 1057.7999 - val_value_loss: 2.2439 - val_policy_loss: 2065.4893
# Epoch 3/10
# 1638/1638 [==============================] - 0s 120us/step - loss: 29.8165 - value_loss: 2.0879 - policy_loss: 6.8609 - val_loss: 183.3490 - val_value_loss: 2.2439 - val_policy_loss: 309.8947
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - 4 batches")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(50)
losses_3 = np.ones(50) - wins_3 - draws_3
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_3, label="win ratio")
plt.plot(x, draws_3, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_3, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
print(wins_3)
print(draws_3)
print(losses_3)
# Out:
# [0.74, 0.78, 0.86, 0.82, 0.72, 0.72, 0.7, 0.86, 0.7, 0.72, 0.8, 0.7, 0.78, 0.78, 0.82, 0.54, 0.72, 0.88, 0.84, 0.68, 0.62, 0.7, 0.74, 0.68, 0.86, 0.72, 0.54, 0.68, 0.72, 0.72, 0.7, 0.76, 0.58, 0.72, 0.76, 0.82, 0.74, 0.84, 0.78, 0.76, 0.7, 0.7, 0.82, 0.66, 0.52, 0.78, 0.8, 0.68, 0.8, 0.88]
# [0.02, 0.06, 0.06, 0.02, 0.06, 0.04, 0.0, 0.02, 0.06, 0.0, 0.04, 0.12, 0.04, 0.04, 0.0, 0.1, 0.06, 0.0, 0.02, 0.08, 0.06, 0.08, 0.04, 0.08, 0.0, 0.08, 0.1, 0.08, 0.08, 0.06, 0.04, 0.0, 0.1, 0.04, 0.02, 0.02, 0.08, 0.02, 0.06, 0.06, 0.1, 0.06, 0.06, 0.14, 0.12, 0.08, 0.04, 0.1, 0.08, 0.02]
# [0.24 0.16 0.08 0.16 0.22 0.24 0.3  0.12 0.24 0.28 0.16 0.18 0.18 0.18
#  0.18 0.36 0.22 0.12 0.14 0.24 0.32 0.22 0.22 0.24 0.14 0.2  0.36 0.24
#  0.2  0.22 0.26 0.24 0.32 0.24 0.22 0.16 0.18 0.14 0.16 0.18 0.2  0.24
#  0.12 0.2  0.36 0.14 0.16 0.22 0.12 0.1 ]

# %% [markdown]
# ## Evaluation

# %%
def smooth(data, window_size):
    return np.convolve(data, np.ones((window_size,))/window_size, mode='valid')

# %% [markdown]
# ### Win rate

# %%
wins_1 = [0.5, 0.44, 0.6, 0.82, 0.9, 0.88, 0.84, 0.86, 0.74, 0.88, 0.86, 0.84, 0.74, 0.78, 0.8, 0.92, 0.82, 0.76, 0.86, 0.88, 0.86, 0.62, 0.88, 0.76, 0.72, 0.76, 0.76, 0.88, 0.86, 0.9, 0.76, 0.8, 0.8, 0.8, 0.74, 0.76, 0.86, 0.86, 0.8, 0.86, 0.76, 0.72, 0.9, 0.72, 0.84, 0.84, 0.84, 0.7, 0.76, 0.86]
draws_1 = [0.04, 0.04, 0.08, 0.0, 0.0, 0.0, 0.02, 0.04, 0.04, 0.02, 0.04, 0.02, 0.06, 0.08, 0.04, 0.0, 0.04, 0.0, 0.0, 0.02, 0.0, 0.12, 0.02, 0.02, 0.0, 0.04, 0.08, 0.0, 0.02, 0.0, 0.04, 0.04, 0.0, 0.02, 0.04, 0.0, 0.04, 0.04, 0.0, 0.0, 0.08, 0.04, 0.0, 0.02, 0.04, 0.0, 0.02, 0.04, 0.02, 0.04]
losses_1 = np.ones(50) - wins_1 - draws_1

wins_2 = [0.42, 0.64, 0.76, 0.7, 0.78, 0.8, 0.76, 0.76, 0.72, 0.76, 0.78, 0.76, 0.9, 0.84, 0.82, 0.76, 0.8, 0.82, 0.9, 0.66, 0.82, 0.74, 0.82, 0.9, 0.8, 0.72, 0.76, 0.62, 0.86, 0.76, 0.72, 0.74, 0.74, 0.82, 0.72, 0.6, 0.9, 0.86, 0.64, 0.78, 0.72, 0.82, 0.78, 0.8, 0.76, 0.86, 0.88, 0.6, 0.76, 0.8]
draws_2 = [0.16, 0.08, 0.04, 0.06, 0.02, 0.04, 0.04, 0.04, 0.04, 0.0, 0.06, 0.06, 0.0, 0.04, 0.04, 0.12, 0.06, 0.06, 0.0, 0.12, 0.06, 0.06, 0.0, 0.04, 0.04, 0.04, 0.04, 0.08, 0.02, 0.04, 0.06, 0.14, 0.06, 0.08, 0.02, 0.08, 0.04, 0.04, 0.1, 0.02, 0.1, 0.02, 0.02, 0.06, 0.04, 0.04, 0.02, 0.1, 0.02, 0.02]
losses_2 = np.ones(50) - wins_2 - draws_2

wins_3 = [0.74, 0.78, 0.86, 0.82, 0.72, 0.72, 0.7, 0.86, 0.7, 0.72, 0.8, 0.7, 0.78, 0.78, 0.82, 0.54, 0.72, 0.88, 0.84, 0.68, 0.62, 0.7, 0.74, 0.68, 0.86, 0.72, 0.54, 0.68, 0.72, 0.72, 0.7, 0.76, 0.58, 0.72, 0.76, 0.82, 0.74, 0.84, 0.78, 0.76, 0.7, 0.7, 0.82, 0.66, 0.52, 0.78, 0.8, 0.68, 0.8, 0.88] 
draws_3 = [0.02, 0.06, 0.06, 0.02, 0.06, 0.04, 0.0, 0.02, 0.06, 0.0, 0.04, 0.12, 0.04, 0.04, 0.0, 0.1, 0.06, 0.0, 0.02, 0.08, 0.06, 0.08, 0.04, 0.08, 0.0, 0.08, 0.1, 0.08, 0.08, 0.06, 0.04, 0.0, 0.1, 0.04, 0.02, 0.02, 0.08, 0.02, 0.06, 0.06, 0.1, 0.06, 0.06, 0.14, 0.12, 0.08, 0.04, 0.1, 0.08, 0.02]
losses_3 = np.ones(50) - wins_3 - draws_3

# %%
window_size = 5

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Win ratio")

plt.xlabel("iteration")
plt.ylabel("win ratio")

x = np.arange(50-window_size+1)

plt.plot(x, smooth(wins_1,window_size), label="1 batch")
plt.plot(x, smooth(wins_2,window_size), label="2 batches")
plt.plot(x, smooth(wins_3,window_size), label="4 batches")

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### Wins + draws rate

# %%
window_size = 5

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Win + draw ratio")

plt.xlabel("iteration")
plt.ylabel("win + draw ratio")

x = np.arange(50-window_size+1)

win_draw_1 = np.array(wins_1) + np.array(draws_1)
win_draw_2 = np.array(wins_2) + np.array(draws_2)
win_draw_3 = np.array(wins_3) + np.array(draws_3)

plt.plot(x, smooth(win_draw_1,window_size), label="1 batch")
plt.plot(x, smooth(win_draw_2,window_size), label="2 batches")
plt.plot(x, smooth(win_draw_3,window_size), label="4 batches")

plt.legend(loc=3)
plt.show()

# %% [markdown]
# ### Training loss

# %%
# import data
train_loss_1 = pd.read_csv("tictactoe_batches/run_tictactoe_1_batch-tag-loss.csv")
train_loss_1 = train_loss_1['Value'].values

train_loss_2 = pd.read_csv("tictactoe_batches/run_tictactoe_2_batches-tag-loss.csv")
train_loss_2 = train_loss_2['Value'].values

train_loss_3 = pd.read_csv("tictactoe_batches/run_tictactoe_4_batches-tag-loss.csv")
train_loss_3 = train_loss_3['Value'].values

# length 
print(train_loss_1.shape)
print(train_loss_2.shape)
print(train_loss_3.shape)
# Out:
# (500,)
# (500,)
# (500,)

# %%
window_size = 10
first_iteration = 50

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Training loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(500-window_size+1 - first_iteration)+first_iteration

plt.plot(x, smooth(train_loss_1[first_iteration:],window_size), label="1 batch")
plt.plot(x, smooth(train_loss_2[first_iteration:],window_size), label="2 batches")
plt.plot(x, smooth(train_loss_3[first_iteration:],window_size), label="4 batches")

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### Validation loss

# %%
# import data
val_loss_1 = pd.read_csv("tictactoe_batches/run_tictactoe_1_batch-tag-val_loss.csv")
val_loss_1 = val_loss_1['Value'].values

val_loss_2 = pd.read_csv("tictactoe_batches/run_tictactoe_2_batches-tag-val_loss.csv")
val_loss_2 = val_loss_2['Value'].values

val_loss_3 = pd.read_csv("tictactoe_batches/run_tictactoe_4_batches-tag-val_loss.csv")
val_loss_3 = val_loss_3['Value'].values

# length 
print(val_loss_1.shape)
print(val_loss_2.shape)
print(val_loss_3.shape)
# Out:
# (500,)
# (500,)
# (500,)

# %%
window_size = 10
first_iteration = 50

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Validation loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(500-window_size+1 - first_iteration) + first_iteration

plt.plot(x, smooth(train_loss_1[first_iteration:],window_size), label="1 batch")
plt.plot(x, smooth(train_loss_2[first_iteration:],window_size), label="2 batches")
plt.plot(x, smooth(train_loss_3[first_iteration:],window_size), label="4 batches")

plt.legend(loc=2)
plt.show()
