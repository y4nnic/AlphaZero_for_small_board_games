# %% [markdown]
# # Experiment: TicTacToe - Regularization Strength

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

from pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## regularization strength 0.01

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 2,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.2, 
    'regularization_strength': 0.01,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_reg_strength_0_01", "TicTacToe")

# %%
wins_1, draws_1 = test_pipeline.run(30)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_reg_strength_0_01_ep_0
# iteration 0 | optimization
# num_positions: 1024
# model_X shape: (1024, 3, 3, 3)
# model_y_outcomes: (1024,)
# model_y_probabilities: (1024, 9)
# Train on 819 samples, validate on 205 samples
# Epoch 1/10
# 819/819 [==============================] - 3s 4ms/step - loss: 579.5383 - value_loss: 1.6171 - policy_loss: 43.3527 - val_loss: 8767585.0000 - val_value_loss: 2.2293 - val_policy_loss: 17532794.0000
# Epoch 2/10
# 819/819 [==============================] - 0s 126us/step - loss: 1074.9742 - value_loss: 2.1795 - policy_loss: 62.1015 - val_loss: 707.4793 - val_value_loss: 2.2293 - val_policy_loss: 54.3296
# Epoch 3/10
# 819/819 [==============================] - 0s 126us/step - loss: 646.4736 - value_loss: 2.1795 - policy_loss: 11.0366 - val_loss: 468.7942 - val_value_loss: 2.2293 - val_policy_loss: 2.2211
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - regularization strength 0.01")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(30)
losses_1 = np.ones(30) - wins_1 - draws_1
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_1, label="win ratio")
plt.plot(x, draws_1, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_1, label="loss ratio")

plt.legend(loc=3)
plt.show()

# %%
print(wins_1)
print(draws_1)
print(losses_1)
# Out:
# [0.94, 0.78, 0.64, 0.64, 0.76, 0.8, 0.82, 0.78, 0.42, 0.4, 0.76, 0.94, 0.88, 0.8, 0.86, 0.76, 0.7, 0.74, 0.44, 0.84, 0.9, 0.82, 0.82, 0.72, 0.86, 0.86, 0.82, 0.86, 0.86, 0.76]
# [0.0, 0.02, 0.16, 0.04, 0.04, 0.02, 0.02, 0.04, 0.18, 0.28, 0.06, 0.0, 0.0, 0.1, 0.08, 0.04, 0.08, 0.04, 0.14, 0.04, 0.04, 0.0, 0.0, 0.02, 0.02, 0.0, 0.02, 0.0, 0.0, 0.02]
# [0.06 0.2  0.2  0.32 0.2  0.18 0.16 0.18 0.4  0.32 0.18 0.06 0.12 0.1
#  0.06 0.2  0.22 0.22 0.42 0.12 0.06 0.18 0.18 0.26 0.12 0.14 0.16 0.14
#  0.14 0.22]

# %% [markdown]
# ## regularization strength 0.1

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 2,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.2, 
    'regularization_strength': 0.1,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_reg_strength_0_1", "TicTacToe")

# %%
wins_4, draws_4 = test_pipeline.run(30)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_reg_strength_0_1_ep_0
# iteration 0 | optimization
# num_positions: 1024
# model_X shape: (1024, 3, 3, 3)
# model_y_outcomes: (1024,)
# model_y_probabilities: (1024, 9)
# Train on 819 samples, validate on 205 samples
# Epoch 1/10
# 819/819 [==============================] - 3s 4ms/step - loss: 4906.2902 - value_loss: 1.6639 - policy_loss: 32.9108 - val_loss: 1663.8457 - val_value_loss: 1.7122 - val_policy_loss: 374.5440
# Epoch 2/10
# 819/819 [==============================] - 0s 128us/step - loss: 2391.9134 - value_loss: 1.7912 - policy_loss: 31.5162 - val_loss: 8307.7725 - val_value_loss: 1.7122 - val_policy_loss: 2177.7266
# Epoch 3/10
# 819/819 [==============================] - 0s 129us/step - loss: 5973.8529 - value_loss: 1.7912 - policy_loss: 11.0304 - val_loss: 856.3712 - val_value_loss: 1.7122 - val_policy_loss: 2.2314
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - regularization strength 0.1")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(30)
losses_4 = np.ones(30) - wins_4 - draws_4
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_4, label="win ratio")
plt.plot(x, draws_4, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_4, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
print(wins_4)
print(draws_4)
print(losses_4)
# Out:
# [0.88, 0.66, 0.9, 0.78, 0.74, 0.82, 0.86, 0.86, 0.74, 0.76, 0.84, 0.82, 0.78, 0.88, 0.86, 0.76, 0.7, 0.84, 0.88, 0.82, 0.8, 0.78, 0.76, 0.9, 0.82, 0.82, 0.82, 0.8, 0.72, 0.7]
# [0.02, 0.16, 0.0, 0.06, 0.04, 0.0, 0.06, 0.0, 0.08, 0.02, 0.02, 0.08, 0.04, 0.02, 0.0, 0.04, 0.02, 0.02, 0.06, 0.02, 0.06, 0.02, 0.02, 0.0, 0.04, 0.04, 0.02, 0.08, 0.04, 0.04]
# [0.1  0.18 0.1  0.16 0.22 0.18 0.08 0.14 0.18 0.22 0.14 0.1  0.18 0.1
#  0.14 0.2  0.28 0.14 0.06 0.16 0.14 0.2  0.22 0.1  0.14 0.14 0.16 0.12
#  0.24 0.26]

# %% [markdown]
# ## regularization strength 0.001

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 2,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.2, 
    'regularization_strength': 0.001,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_reg_strength_0_001", "TicTacToe")

# %%
wins_2, draws_2 = test_pipeline.run(30)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_reg_strength_0_001_ep_0
# iteration 0 | optimization
# num_positions: 1024
# model_X shape: (1024, 3, 3, 3)
# model_y_outcomes: (1024,)
# model_y_probabilities: (1024, 9)
# Train on 819 samples, validate on 205 samples
# Epoch 1/10
# 819/819 [==============================] - 3s 4ms/step - loss: 86.8595 - value_loss: 1.8126 - policy_loss: 56.8643 - val_loss: 549088768.0000 - val_value_loss: 2.4195 - val_policy_loss: 1098177024.0000
# Epoch 2/10
# 819/819 [==============================] - 0s 133us/step - loss: 440.2411 - value_loss: 2.1685 - policy_loss: 75.9350 - val_loss: 16300.4561 - val_value_loss: 2.4195 - val_policy_loss: 31501.0781
# Epoch 3/10
# 819/819 [==============================] - 0s 131us/step - loss: 554.3276 - value_loss: 2.1685 - policy_loss: 12.7119 - val_loss: 954.9175 - val_value_loss: 2.4195 - val_policy_loss: 910.4520
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - regularization strength 0.001")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(30)
losses_2 = np.ones(30) - wins_2 - draws_2
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_2, label="win ratio")
plt.plot(x, draws_2, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_2, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
print(wins_2)
print(draws_2)
print(losses_2)
# Out:
# [0.8, 0.82, 0.78, 0.78, 0.82, 0.84, 0.84, 0.68, 0.76, 0.82, 0.82, 0.66, 0.9, 0.9, 0.82, 0.78, 0.9, 0.9, 0.44, 0.76, 0.78, 0.82, 0.52, 0.84, 0.78, 0.84, 0.86, 0.82, 0.86, 0.82]
# [0.02, 0.0, 0.0, 0.04, 0.04, 0.0, 0.02, 0.14, 0.02, 0.02, 0.0, 0.1, 0.04, 0.02, 0.0, 0.04, 0.0, 0.04, 0.02, 0.02, 0.04, 0.0, 0.18, 0.02, 0.0, 0.02, 0.0, 0.0, 0.02, 0.08]
# [0.18 0.18 0.22 0.18 0.14 0.16 0.14 0.18 0.22 0.16 0.18 0.24 0.06 0.08
#  0.18 0.18 0.1  0.06 0.54 0.22 0.18 0.18 0.3  0.14 0.22 0.14 0.14 0.18
#  0.12 0.1 ]

# %% [markdown]
# ## regularization strength 0.0001

# %%
MCTS = {
    'c_puct': 1.0,
    'dir_alpha': 0.5,
    'dir_epsilon': 0.25
}

OPTIMISATION = {
    'num_batches': 2,
    'batch_size': 512,
    'num_epochs': 10
}

EVALUATION = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 0,
}

SELF_PLAY = {
    'num_games': 50,
    'num_simulations': 25,
    'temperature': 1
}

NEURAL_NETWORKS = {
    'learning_rate': 0.2, 
    'regularization_strength': 0.0001,
    'num_filters_policy': 256,
    'num_filters_value': 256,
    'num_filters_tower': 256,
    'num_residual_blocks': 5,
    'kernel_size_tower': 3,
    'hidden_dim_value': 256
}

# %%
test_pipeline = Pipeline("tictactoe_reg_strength_0_0001", "TicTacToe")

# %%
wins_3, draws_3 = test_pipeline.run(30)
# Out:
# iteration 0 | self-play
# saving memory position_memory_tictactoe_reg_strength_0_0001_ep_0
# iteration 0 | optimization
# num_positions: 1024
# model_X shape: (1024, 3, 3, 3)
# model_y_outcomes: (1024,)
# model_y_probabilities: (1024, 9)
# Train on 819 samples, validate on 205 samples
# Epoch 1/10
# 819/819 [==============================] - 3s 4ms/step - loss: 31.5849 - value_loss: 1.3373 - policy_loss: 50.2152 - val_loss: 28785716.0000 - val_value_loss: 1.5951 - val_policy_loss: 57571344.0000
# Epoch 2/10
# 819/819 [==============================] - 0s 140us/step - loss: 95.3940 - value_loss: 1.7460 - policy_loss: 74.9989 - val_loss: 190802.2812 - val_value_loss: 1.5951 - val_policy_loss: 381375.0312
# Epoch 3/10
# 819/819 [==============================] - 0s 132us/step - loss: 134.7104 - value_loss: 1.7460 - policy_loss: 14.5920 - val_loss: 15290.4238 - val_value_loss: 1.5951 - val_policy_loss: 30224.1562
# Epoch 4/10
# ...

# %%
fig = plt.figure()

plt.title("Evaluation - regularization strength 0.0001")

plt.xlabel("iteration")
plt.ylabel("ratio")

x = np.arange(30)
losses_3 = np.ones(30) - wins_3 - draws_3
# no_loss = np.zeros(50) + wins +draws

plt.plot(x, wins_3, label="win ratio")
plt.plot(x, draws_3, label="draw ratio")
#plt.plot(x, no_loss, label="no loss ratio")
plt.plot(x, losses_3, label="loss ratio")

plt.legend(loc=2)
plt.show()

# %%
print(wins_3)
print(draws_3)
print(losses_3)
# Out:
# [0.44, 0.7, 0.84, 0.82, 0.84, 0.82, 0.86, 0.72, 0.98, 0.78, 0.94, 0.86, 0.78, 0.92, 0.84, 0.86, 0.6, 0.82, 0.84, 0.86, 0.86, 0.8, 0.8, 0.84, 0.76, 0.78, 0.76, 0.9, 0.88, 0.78]
# [0.06, 0.04, 0.04, 0.08, 0.04, 0.02, 0.02, 0.06, 0.0, 0.08, 0.0, 0.04, 0.0, 0.0, 0.02, 0.04, 0.08, 0.04, 0.02, 0.0, 0.02, 0.06, 0.02, 0.04, 0.04, 0.08, 0.04, 0.02, 0.0, 0.02]
# [0.5  0.26 0.12 0.1  0.12 0.16 0.12 0.22 0.02 0.14 0.06 0.1  0.22 0.08
#  0.14 0.1  0.32 0.14 0.14 0.14 0.12 0.14 0.18 0.12 0.2  0.14 0.2  0.08
#  0.12 0.2 ]

# %% [markdown]
# ## Evaluation

# %%
def smooth(data, window_size):
    return np.convolve(data, np.ones((window_size,))/window_size, mode='valid')

# %% [markdown]
# ### Win rate

# %%
wins_1 = [0.94, 0.78, 0.64, 0.64, 0.76, 0.8, 0.82, 0.78, 0.42, 0.4, 0.76, 0.94, 0.88, 0.8, 0.86, 0.76, 0.7, 0.74, 0.44, 0.84, 0.9, 0.82, 0.82, 0.72, 0.86, 0.86, 0.82, 0.86, 0.86, 0.76]
draws_1 = [0.0, 0.02, 0.16, 0.04, 0.04, 0.02, 0.02, 0.04, 0.18, 0.28, 0.06, 0.0, 0.0, 0.1, 0.08, 0.04, 0.08, 0.04, 0.14, 0.04, 0.04, 0.0, 0.0, 0.02, 0.02, 0.0, 0.02, 0.0, 0.0, 0.02]
losses_1 = np.ones(30) - wins_1 - draws_1

wins_2 = [0.8, 0.82, 0.78, 0.78, 0.82, 0.84, 0.84, 0.68, 0.76, 0.82, 0.82, 0.66, 0.9, 0.9, 0.82, 0.78, 0.9, 0.9, 0.44, 0.76, 0.78, 0.82, 0.52, 0.84, 0.78, 0.84, 0.86, 0.82, 0.86, 0.82]
draws_2 = [0.02, 0.0, 0.0, 0.04, 0.04, 0.0, 0.02, 0.14, 0.02, 0.02, 0.0, 0.1, 0.04, 0.02, 0.0, 0.04, 0.0, 0.04, 0.02, 0.02, 0.04, 0.0, 0.18, 0.02, 0.0, 0.02, 0.0, 0.0, 0.02, 0.08]
losses_2 = np.ones(30) - wins_2 - draws_2

wins_3 = [0.44, 0.7, 0.84, 0.82, 0.84, 0.82, 0.86, 0.72, 0.98, 0.78, 0.94, 0.86, 0.78, 0.92, 0.84, 0.86, 0.6, 0.82, 0.84, 0.86, 0.86, 0.8, 0.8, 0.84, 0.76, 0.78, 0.76, 0.9, 0.88, 0.78] 
draws_3 = [0.06, 0.04, 0.04, 0.08, 0.04, 0.02, 0.02, 0.06, 0.0, 0.08, 0.0, 0.04, 0.0, 0.0, 0.02, 0.04, 0.08, 0.04, 0.02, 0.0, 0.02, 0.06, 0.02, 0.04, 0.04, 0.08, 0.04, 0.02, 0.0, 0.02]
losses_3 = np.ones(30) - wins_3 - draws_3

wins_4 = [0.88, 0.66, 0.9, 0.78, 0.74, 0.82, 0.86, 0.86, 0.74, 0.76, 0.84, 0.82, 0.78, 0.88, 0.86, 0.76, 0.7, 0.84, 0.88, 0.82, 0.8, 0.78, 0.76, 0.9, 0.82, 0.82, 0.82, 0.8, 0.72, 0.7]
draws_4 = [0.02, 0.16, 0.0, 0.06, 0.04, 0.0, 0.06, 0.0, 0.08, 0.02, 0.02, 0.08, 0.04, 0.02, 0.0, 0.04, 0.02, 0.02, 0.06, 0.02, 0.06, 0.02, 0.02, 0.0, 0.04, 0.04, 0.02, 0.08, 0.04, 0.04]
losses_4 = np.ones(30) - wins_4 -draws_4

# %%
window_size = 3

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Win ratio")

plt.xlabel("iteration")
plt.ylabel("win ratio")

x = np.arange(30 - window_size + 1)

plt.plot(x, smooth(wins_1, window_size), label="reg strength 0.01")
plt.plot(x, smooth(wins_2, window_size), label="reg strength 0.001")
plt.plot(x, smooth(wins_3, window_size), label="reg strength 0.0001")
plt.plot(x, smooth(wins_4, window_size), label="reg strength 0.1")

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### Training loss

# %%
# import data
train_loss_1 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_1-tag-loss.csv")
train_loss_1 = train_loss_1['Value'].values

train_loss_2 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_01-tag-loss.csv")
train_loss_2 = train_loss_2['Value'].values

train_loss_3 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_001-tag-loss.csv")
train_loss_3 = train_loss_3['Value'].values

train_loss_4 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_0001-tag-loss.csv")
train_loss_4 = train_loss_4['Value'].values
# length 
print(train_loss_1.shape)
print(train_loss_2.shape)
print(train_loss_3.shape)
# Out:
# (300,)
# (300,)
# (300,)

# %%
window_size = 1
first_iteration = 20

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Training loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(300-window_size+1 - first_iteration)+first_iteration

plt.plot(x, smooth(train_loss_1[first_iteration:],window_size), label="regularization strength 0.1")
plt.plot(x, smooth(train_loss_2[first_iteration:],window_size), label="regularization strength 0.01")
plt.plot(x, smooth(train_loss_3[first_iteration:],window_size), label="regularization strength 0.001")
plt.plot(x, smooth(train_loss_4[first_iteration:],window_size), label="regularization strength 0.0001")


plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### Validation loss

# %%
# import data
val_loss_1 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_1-tag-val_loss.csv")
val_loss_1 = val_loss_1['Value'].values

val_loss_2 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_01-tag-val_loss.csv")
val_loss_2 = val_loss_2['Value'].values

val_loss_3 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_001-tag-val_loss.csv")
val_loss_3 = val_loss_3['Value'].values

val_loss_4 = pd.read_csv("tictactoe_reg/run_tictactoe_reg_strength_0_0001-tag-val_loss.csv")
val_loss_4 = val_loss_4['Value'].values

# length 
print(val_loss_1.shape)
print(val_loss_2.shape)
print(val_loss_3.shape)
print(val_loss_4.shape)
# Out:
# (300,)
# (300,)
# (300,)
# (300,)

# %%
window_size = 10
first_iteration = 20
last_iteration = 100

fig = plt.figure(figsize=(10,7))
plt.title("Evaluation - Validation loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(300 - window_size + 1 - first_iteration -(300-last_iteration)) + first_iteration

plt.plot(x, smooth(val_loss_1[first_iteration:last_iteration],window_size), label="regularization strength 0.1")
plt.plot(x, smooth(val_loss_2[first_iteration:last_iteration],window_size), label="regularization strength 0.01")
plt.plot(x, smooth(val_loss_3[first_iteration:last_iteration],window_size), label="regularization strength 0.001")
plt.plot(x, smooth(val_loss_3[first_iteration:last_iteration],window_size), label="regularization strength 0.0001")

plt.legend(loc=2)
plt.show()

fig = plt.figure(figsize=(10,7))
plt.title("Evaluation - Validation loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(300 - window_size + 1 - first_iteration -(300-last_iteration)) + first_iteration

plt.plot(x, smooth(val_loss_1[first_iteration:last_iteration],window_size), label="regularization strength 0.1")

plt.legend(loc=2)
plt.show()

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Validation loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(300 - window_size + 1 - first_iteration -(300-last_iteration)) + first_iteration

plt.plot(x, smooth(val_loss_2[first_iteration:last_iteration],window_size), label="regularization strength 0.01")

plt.legend(loc=2)
plt.show()

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Validation loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(300 - window_size + 1 - first_iteration -(300-last_iteration)) + first_iteration

plt.plot(x, smooth(val_loss_3[first_iteration:last_iteration],window_size), label="regularization strength 0.001")

plt.legend(loc=2)
plt.show()

fig = plt.figure(figsize=(10,7))

plt.title("Evaluation - Validation loss")

plt.xlabel("epoch")
plt.ylabel("loss")

x = np.arange(300 - window_size + 1 - first_iteration -(300-last_iteration)) + first_iteration

plt.plot(x, smooth(val_loss_4[first_iteration:last_iteration],window_size), label="regularization strength 0.0001")

plt.legend(loc=2)
plt.show()
